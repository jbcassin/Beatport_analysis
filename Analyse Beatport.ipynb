# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("beatport_2021jan.csv")
data.head()
# Out:
#      1-ZCRm  2-Energym  3-EnergyEntropym  4-SpectralCentroidm  \
# 0  0.079425   0.089604          3.120111             0.214365
# 1  0.049946   0.066472          3.099221             0.164947
# 2  0.073689   0.072842          3.114776             0.201525
# 3  0.074295   0.143877          3.184615             0.196423
# 4  0.092794   0.061911          3.146484             0.219616
#
#    5-SpectralSpreadm  6-SpectralEntropym  7-SpectralFluxm  8-SpectralRolloffm  \
# 0           0.234222            0.633007         0.012340            0.150022
# 1           0.217858            0.397340         0.018363            0.079529
# 2           0.239958            0.554679         0.013654            0.116526
# 3           0.231027            0.632171         0.013408            0.098109
# 4           0.250961            0.716576         0.011783            0.162721
#
#    9-MFCCs1m  10-MFCCs2m  ...  86-beats_loudness_band_ratio.mean6  \
# 0 -23.770716    2.118928  ...                            0.300503
# 1 -23.910628    2.304411  ...                            0.009315
# 2 -23.883897    2.080150  ...                            0.049592
# 3 -22.323175    2.178740  ...                            0.017663
# 4 -23.549247    2.516020  ...                            0.013010
#
#    87-beats_loudness_band_ratio.stdev1  88-beats_loudness_band_ratio.stdev2  \
# 0                             0.248348                             0.131157
# 1                             0.358702                             0.160241
# 2                             0.460217                             0.033355
# 3                             0.365594                             0.086201
# 4                             0.260539                             0.102057
#
#    89-beats_loudness_band_ratio.stdev3  90-beats_loudness_band_ratio.stdev4  \
# 0                             0.109375                             0.070657
# 1                             0.164309                             0.112424
# 2                             0.317956                             0.089679
# 3                             0.221063                             0.137246
# 4                             0.098144                             0.089875
#
#    91-beats_loudness_band_ratio.stdev5  92-beats_loudness_band_ratio.stdev6  \
# 0                             0.027211                             0.223204
# 1                             0.067507                             0.021833
# 2                             0.078159                             0.078740
# 3                             0.041445                             0.028583
# 4                             0.025987                             0.031015
#
#         genre       artist                                track
# 0  Afro House  Javi Colors            Feeling Good-Original Mix
# 1  Afro House   Notre Dame                  Kaneba-Original Mix
# 2  Afro House  Lunar Plane        Children Of Rain-Original Mix
# 3  Afro House        Bonga  Mona Ki Ngi Xica-Pablo Fierro Remix
# 4  Afro House        Yamil             De Todo Se Aprende-Remix
#
# [5 rows x 95 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3200 entries, 0 to 3199
# Data columns (total 95 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   1-ZCRm                               3200 non-null   float64
#  1   2-Energym                            3200 non-null   float64
#  2   3-EnergyEntropym                     3200 non-null   float64
#  3   4-SpectralCentroidm                  3200 non-null   float64
#  4   5-SpectralSpreadm                    3200 non-null   float64
#  5   6-SpectralEntropym                   3200 non-null   float64
#  6   7-SpectralFluxm                      3200 non-null   float64
#  7   8-SpectralRolloffm                   3200 non-null   float64
#  8   9-MFCCs1m                            3200 non-null   float64
#  9   10-MFCCs2m                           3200 non-null   float64
#  10  11-MFCCs3m                           3200 non-null   float64
#  11  12-MFCCs4m                           3200 non-null   float64
#  12  13-MFCCs5m                           3200 non-null   float64
#  13  14-MFCCs6m                           3200 non-null   float64
#  14  15-MFCCs7m                           3200 non-null   float64
#  15  16-MFCCs8m                           3200 non-null   float64
#  16  17-MFCCs9m                           3200 non-null   float64
#  17  18-MFCCs10m                          3200 non-null   float64
#  18  19-MFCCs11m                          3200 non-null   float64
#  19  20-MFCCs12m                          3200 non-null   float64
#  20  21-MFCCs13m                          3200 non-null   float64
#  21  22-ChromaVector1m                    3200 non-null   float64
#  22  23-ChromaVector2m                    3200 non-null   float64
#  23  24-ChromaVector3m                    3200 non-null   float64
#  24  25-ChromaVector4m                    3200 non-null   float64
#  25  26-ChromaVector5m                    3200 non-null   float64
#  26  27-ChromaVector6m                    3200 non-null   float64
#  27  28-ChromaVector7m                    3200 non-null   float64
#  28  29-ChromaVector8m                    3200 non-null   float64
#  29  30-ChromaVector9m                    3200 non-null   float64
#  30  31-ChromaVector10m                   3200 non-null   float64
#  31  32-ChromaVector11m                   3200 non-null   float64
#  32  33-ChromaVector12m                   3200 non-null   float64
#  33  34-ChromaDeviationm                  3200 non-null   float64
#  34  35-ZCRstd                            3200 non-null   float64
#  35  36-Energystd                         3200 non-null   float64
#  36  37-EnergyEntropystd                  3200 non-null   float64
#  37  38-SpectralCentroidstd               3200 non-null   float64
#  38  39-SpectralSpreadstd                 3200 non-null   float64
#  39  40-SpectralEntropystd                3200 non-null   float64
#  40  41-SpectralFluxstd                   3200 non-null   float64
#  41  42-SpectralRolloffstd                3200 non-null   float64
#  42  43-MFCCs1std                         3200 non-null   float64
#  43  44-MFCCs2std                         3200 non-null   float64
#  44  45-MFCCs3std                         3200 non-null   float64
#  45  46-MFCCs4std                         3200 non-null   float64
#  46  47-MFCCs5std                         3200 non-null   float64
#  47  48-MFCCs6std                         3200 non-null   float64
#  48  49-MFCCs7std                         3200 non-null   float64
#  49  50-MFCCs8std                         3200 non-null   float64
#  50  51-MFCCs9std                         3200 non-null   float64
#  51  52-MFCCs10std                        3200 non-null   float64
#  52  53-MFCCs11std                        3200 non-null   float64
#  53  54-MFCCs12std                        3200 non-null   float64
#  54  55-MFCCs13std                        3200 non-null   float64
#  55  56-ChromaVector1std                  3200 non-null   float64
#  56  57-ChromaVector2std                  3200 non-null   float64
#  57  58-ChromaVector3std                  3200 non-null   float64
#  58  59-ChromaVector4std                  3200 non-null   float64
#  59  60-ChromaVector5std                  3200 non-null   float64
#  60  61-ChromaVector6std                  3200 non-null   float64
#  61  62-ChromaVector7std                  3200 non-null   float64
#  62  63-ChromaVector8std                  3200 non-null   float64
#  63  64-ChromaVector9std                  3200 non-null   float64
#  64  65-ChromaVector10std                 3200 non-null   float64
#  65  66-ChromaVector11std                 3200 non-null   float64
#  66  67-ChromaVector12std                 3200 non-null   float64
#  67  68-ChromaDeviationstd                3200 non-null   float64
#  68  69-BPM                               3200 non-null   float64
#  69  70-BPMconf                           3200 non-null   float64
#  70  71-BPMessentia                       3200 non-null   float64
#  71  72-bpm_histogram_first_peak_bpm      3200 non-null   int64
#  72  73-bpm_histogram_first_peak_weight   3200 non-null   float64
#  73  74-bpm_histogram_second_peak_bpm     3200 non-null   int64
#  74  75-bpm_histogram_second_peak_spread  3200 non-null   float64
#  75  76-bpm_histogram_second_peak_weight  3200 non-null   float64
#  76  77-danceability                      3200 non-null   float64
#  77  78-beats_loudness.mean               3200 non-null   float64
#  78  79-beats_loudness.stdev              3200 non-null   float64
#  79  80-onset_rate                        3200 non-null   float64
#  80  81-beats_loudness_band_ratio.mean1   3200 non-null   float64
#  81  82-beats_loudness_band_ratio.mean2   3200 non-null   float64
#  82  83-beats_loudness_band_ratio.mean3   3200 non-null   float64
#  83  84-beats_loudness_band_ratio.mean4   3200 non-null   float64
#  84  85-beats_loudness_band_ratio.mean5   3200 non-null   float64
#  85  86-beats_loudness_band_ratio.mean6   3200 non-null   float64
#  86  87-beats_loudness_band_ratio.stdev1  3200 non-null   float64
#  87  88-beats_loudness_band_ratio.stdev2  3200 non-null   float64
#  88  89-beats_loudness_band_ratio.stdev3  3200 non-null   float64
#  89  90-beats_loudness_band_ratio.stdev4  3200 non-null   float64
#  90  91-beats_loudness_band_ratio.stdev5  3200 non-null   float64
#  91  92-beats_loudness_band_ratio.stdev6  3200 non-null   float64
#  92  genre                                3200 non-null   object
#  93  artist                               3200 non-null   object
#  94  track                                3200 non-null   object
# dtypes: float64(90), int64(2), object(3)
# memory usage: 2.3+ MB

# %% [markdown]
# # Index	Name	Description
# 1	Zero Crossing Rate	The rate of sign-changes of the signal during the duration of a particular frame.
#
# 2	Energy	The sum of squares of the signal values, normalized by the respective frame length.
#
# 3	Entropy of Energy	The entropy of sub-frames’ normalized energies. It can be interpreted as a measure of abrupt changes.
#
# 4	Spectral Centroid	The center of gravity of the spectrum.
#
# 5	Spectral Spread	The second central moment of the spectrum.
#
# 6	Spectral Entropy	Entropy of the normalized spectral energies for a set of sub-frames.
#
# 7	Spectral Flux	The squared difference between the normalized magnitudes of the spectra of the two successive frames.
#
# 8	Spectral Rolloff	The frequency below which 90% of the magnitude distribution of the spectrum is concentrated.
#
# 9–21	MFCCs	Mel Frequency Cepstral Coefficients form a cepstral representation where the frequency bands are not linear but distributed according to the mel-scale.
#
# 22–33	Chroma Vector	A 12-element representation of the spectral energy where the bins represent the 12 equal-tempered pitch classes of western-type music (semitone spacing).
#
# 34	Chroma Deviation	The standard deviation of the 12 chroma coefficients.

# %%
data.describe().T
# Out:
#                                       count      mean       std       min  \
# 1-ZCRm                               3200.0  0.104006  0.035362  0.012223
# 2-Energym                            3200.0  0.089752  0.036843  0.003178
# 3-EnergyEntropym                     3200.0  3.105808  0.072755  2.619833
# 4-SpectralCentroidm                  3200.0  0.235237  0.044413  0.086694
# 5-SpectralSpreadm                    3200.0  0.243999  0.022762  0.139144
# ...                                     ...       ...       ...       ...
# 88-beats_loudness_band_ratio.stdev2  3200.0  0.125516  0.057135  0.002549
# 89-beats_loudness_band_ratio.stdev3  3200.0  0.121228  0.055274  0.000427
# 90-beats_loudness_band_ratio.stdev4  3200.0  0.101824  0.047999  0.000699
# 91-beats_loudness_band_ratio.stdev5  3200.0  0.071343  0.037211  0.000043
# 92-beats_loudness_band_ratio.stdev6  3200.0  0.113600  0.065833  0.000003
#
#                                           25%       50%       75%       max
# 1-ZCRm                               0.078451  0.101969  0.127013  0.327391
# 2-Energym                            0.063906  0.085000  0.110436  0.302282
# 3-EnergyEntropym                     3.065788  3.114156  3.156167  3.269744
# 4-SpectralCentroidm                  0.205969  0.237271  0.265276  0.395661
# 5-SpectralSpreadm                    0.230784  0.247267  0.259768  0.318243
# ...                                       ...       ...       ...       ...
# 88-beats_loudness_band_ratio.stdev2  0.083782  0.120705  0.161664  0.376574
# 89-beats_loudness_band_ratio.stdev3  0.082028  0.118167  0.157165  0.333329
# 90-beats_loudness_band_ratio.stdev4  0.068578  0.097487  0.130552  0.370927
# 91-beats_loudness_band_ratio.stdev5  0.044629  0.066696  0.092415  0.248272
# 92-beats_loudness_band_ratio.stdev6  0.065216  0.102868  0.152824  0.403064
#
# [92 rows x 8 columns]

# %%
# nombre de genre
data.genre.nunique()
# Out:
# 32

# %%
# 

store_type_mode = transactions['store_type'].mode()
print("La modalité la plus fréquente de 'store_type' est:", store_type_mode[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 3
#       1 #
# ----> 3 store_type_mode = transactions['store_type'].mode()
#       4 print("La modalité la plus fréquente de 'store_type' est:", store_type_mode[0])
#
# NameError: name 'transactions' is not defined

# %%
# Courbe des BPM
sns.displot(data['71-BPMessentia']);

# %%
# Courbe des BPM
sns.displot(data['77-danceability']);
